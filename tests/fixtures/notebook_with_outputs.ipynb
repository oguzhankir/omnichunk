# %% [markdown]
# # Demo
#
# This is a demo notebook.

# %%
x = 1
y = 2
x + y
# Out:
# 3

# %%
print("hello")
# Out:
# hello

# %% [raw]
# raw cell text

# %%
1 / 0
# Out:
# Traceback...
# ZeroDivisionError: division by zero
